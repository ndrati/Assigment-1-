# %% [markdown]
# Professor: Apostolos Filippas
#
# Class: Web Analytics
#
# Topic: Parsing web content III
#
# **This material was developed by Jie Lu. You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.**
#
# # <center><font color='red'>Scraping data using Twitter's API</font></center>
#
# This notebook details how we can use an API to parse content -- if, of course, the website provides you with an API them. To get introduced to using APIs to parse data, we will examine some scraping examples using Twitter's API.

# %% [markdown]
# # 0. Before class
#
# Make sure you can load all the packages below before coming to class

# %%
# load packages
# Note: please install the Tweepy package if you haven't
#       to do so, run "pip install tweepy" on your command line

# Tweepy allows us to access the twitter API in python
import tweepy  

# Pandas wil lallow us to extract tweets/users and load the data into dataframe 
import pandas as pd

# JSON will allow us to work with JSON files
import json

# json_normalize() will allows us to normalize semi-structured JSON data into a flat table
from pandas.io.json import json_normalize

# %% [markdown]
# ## 1. Authentication
#
#
# Let's begin with some necessary authentication steps!
#
# - To start using Twitter's API, we first have to obtain the correct **authentication keys and tokens**.
# - These keys and tokens allow Twitter to securely identify each user, and protect user privacy
#
# Authentication is handled by the tweepy.AuthHandler class.
# Tweepy tries to make the authentication process as painless as possible for you.
#
# To begin the authentication process we need to:
# - register a client application with Twitter
# - create a new application
#
# If you follow the steps before the class. Once you are done you should have your consumer key and secret. Keep these two handy, as you’ll need them. To find them, go to https://developer.twitter.com/en/apps/ and then click on details:
#
# <br>
# <img src="https://docs.google.com/uc?export=download&id=1fxYeyGrs7lgDg-YlYEdJ7SlRmuQvpWWM" width="800" height="480">
# <br>

# %%
# Variables that contain the credentials to access Twitter API
# Use your own key and tokens instead
consumer_key    = "imqH65lm6swRGWCYmzCRjIBE5"
consumer_secret = "FvIqyOhTnzBtb8C6TjCmJThbRVZduDDVMP4X25MIfC2enL7RGo"
access_key      = "725501506888196096-gdAWRWBX1aQbLU8aLMcBvh5QYs19Y10"
access_secret   = "1TEpIWTm73wBkDF1ANmcDfS5XmEfBndLGP8jDZUexI5fp"

# Setup access to API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)

# create the API object
api = tweepy.API(auth)

# %% [markdown]
# Now, just to make sure it worked, let's check the most recent tweets from our stream.

# %%
# most recent 5 tweets from my stream
recent_tweets = api.home_timeline(count=200)
for tweet in recent_tweets:
    if 'Airbnb' or '@Airbnb' or '#Airbnb' in tweet.text: 
        print(tweet.text)
# Out:
# Top transfer Devin Leary has committed to Kentucky 🏈 https://t.co/0MPn02VMOK
# 𝙎𝙪𝙧𝙫𝙚𝙮 𝙨𝙖𝙮𝙨...
#
# #SicEm | #PersonOverPlayer https://t.co/OaWzoc0KRK
# Let's go! #RIDEHIGH https://t.co/p0HDuRc8Jn
# RT @BoMcNally: Had a blast speaking at the @StanfordFball official visit weekend with some fellow football alumni. Preaching what I’m exper…
# RT @jjordangarrison: COMMITTED! #RideHigh #AGTG 💚🤎 @mark_serve @CoachSpears1 @CoachWulff @coachjmusky https://t.co/ZHMm1iO9eH
# BIG TIME commit out of the Northeast joining the #TunnelWorkersUnion and @StanfordFball https://t.co/SWwq96nwrz
# RT @LouStagner: Yesterday I posted that making "net par" is a solid goal.
#
# I had a conversation with a 7-index friend who said:
#
# "I am not…
# RT @UWTarrant: We've got an easy and fun way for you to show your support for veterans this holiday season! Thanks to our @ArmedForcesBowl…
# The Path... It's Paved By Legends. https://t.co/Q39a1S6HgE
# If you didn't know, I've joined up with @Qb11Sd &amp; @DouglasTS to deliver a weekly podcast - On Monday we recorded ou… https://t.co/AYhn7wpsWI
# Huge congrats to our guy @kyleostendorp who was named College Sports Communicators Academic First-Team All-American… https://t.co/dsJrjU2rV2
# RT @CoachKurtHines: Whoever you are, there is someone who thinks you are perfect.
#
# There is work that will never be done if you don’t do i…
# 🚨 COMMITMENT ALERT 🚨
#
# UCF has landed a commitment from in-state DE Andrew Rumph.
#
# "I'm going to a great program an… https://t.co/yExzpQeW5z
# Miami LB Avery Huff, a top-200 recruit as a 4-star in the Class of 2019, is entering the NCAA transfer portal:… https://t.co/3SLvpZfgbT
# RT @samspiegs: Might want to bookmark this page for National Signing Day Eve -- all the latest intel from myself and @ChadSimmons_ being up…
# .@dodeyingbo ᴀᴘᴘʟʏɪɴɢ ᴛʜᴇ ᴘʀᴇꜱꜱᴜʀᴇ 😤
#
# #DoresInTheNFL | #AnchorDown https://t.co/QgnVKoYenq
# Congratulations to Jake Bobo on being named a First Team Academic All-American! 📚🏈 https://t.co/EuC71SMXcU
# Will Florida State or Louisville flip four-star Florida WR commit Andy Jean?
#
# He tells @RWrightRivals he's locked… https://t.co/YvhxnbJpW6
# Join us at the 247Sports YouTube channel to find out where Amare Snowden is committing tomorrow  👀
#
# 📺:… https://t.co/Lox5tFj31m
# Despite a late visit to Georgia Tech, four-star DB Terrance Love tells @RWrightRivals he's locked in with Auburn:… https://t.co/ctH5xpZRTN
# Michigan State is trending on the @247Sports Transfer Portal Crystal Ball for Texas A&amp;M DL Tunmise Adeleye.… https://t.co/rUqXIaop7M
# Join us at the 247Sports YouTube channel to find out where top-15 transfer Ajani Cornelius is committing tomorrow… https://t.co/IdDywS2jXx
# Three more All-America honors for the Aggies! #GoAgs  https://t.co/UKv6KBH84B
# Reggie Bush skewers NCAA, outgoing president Mark Emmert over Heisman Trophy controversy: https://t.co/FHir2M0KIn https://t.co/Zy54QRiDHr
# Stanford flipped three-star OL Charlie Symonds away from NC State on Tuesday.
#
# The Cardinal class now ranks No. 38… https://t.co/ZuJICpuRAa
# Will five-star DB Peyton Bowen flip from Notre Dame to Oklahoma or Oregon?
#
# @adamgorney looks at the 12 most likely… https://t.co/VfRV51BKEB
# Doesn’t look like #Wisconsin is flipping Owusu. https://t.co/RVw2MS2BaJ
# .@stefondiggs is one of the great ones. ❤️🙏 https://t.co/MQcbCjtzrq
# Stanford scores east coast OL on eve of NSD @Stanford_247 https://t.co/pv8iUCTlGt
# Yesterday, Texas A&amp;M landed four-star dual-threat QB Marcel Reed
#
# @mbpRivals with more on the commitment:… https://t.co/ZApwL22nGG
# Which recruits are expected to sign with Mizzou on Wednesday?
#
# @jarodchamilton has the rundown of the names, inclu… https://t.co/p3nybXRbgG
# Could he be the next great receiver out of USC? Zachariah Branch is ELITE. https://t.co/KDWgk305bF
# RT @UNISWAG: Bowl threads for @SanJoseStateFB
#
# #uniswag
#  https://t.co/TKDUNrWmO6
# 1️⃣ week from today!
#
# 🔜 @FRBowl
# 🏟️ Gerald J. Ford Stadium
#
# 🎟️➡️ https://t.co/2mpwx0u8G2 https://t.co/GAJrV4SVcg
# One more ride today with ⁦@SanJoseStateFB⁩ Wrecking Crew ⁦@cade_hall97⁩ &amp; ⁦@juniorfehoko42⁩ members of the SpartanN… https://t.co/yQRwd8R4Zd
# Coach Traylor wants something done about the P5 schools trying to tamper with G5 rosters 👀 https://t.co/qTqf2T9ZRN
# RT @danielcbritt18: Thank you Montana for the opportunity ❤️ I am officially in the transfer portal with 3 years old eligibility left. http…
# RT @_Almightydee___: Just a few clips of me at DB can’t wait till spring ball @CoachTABurkett @Coach_Mendonca @COSGIANTS_FB https://t.co/7j…
# RT @JWerner247: JUST IN: #Illini, Bret Bielema agree to two-year contract extension that will keep Bielema under contract through 2028 and…
# #Badgers send out a late offer to #Gophers commit Martin Owusu https://t.co/QkxBHb4bGV
# Which programs will be in the biggest spotlight during the Early Signing Period? @RWrightRivals offers five candida… https://t.co/n87H74U4ge
# RT @dj_bandz: I give a fuck less every day 🤷🏽‍♂️
# RT @BudElliott3: 🗣 Why, even with the advent of the portal, you still need to be glued to @247Sports and @CBSSportsHQ @Cover3Podcast for Ea…
# Join us in wishing @anthonyward1_ a Happy Birthday! 🎉 https://t.co/EQDxZ3Hw6H
# Frosty 🧊☃️
# click the link to shop the fit. 🔗 https://t.co/tREA9lcSxY https://t.co/ppxPr1mlAA
# RT @KarlousM: I don’t think it’s him.
# RT @ImDukeDennis: Put your phone down every once in a while 💯
# A look at the top 20 quarterback recruits in 2023 and where they are going 👀 https://t.co/DvWHGnnUsq
# Only FIVE copies of #AthletesAreBrandsToo left on Amazon (more on the way), get yours now before the holiday!
#
# Say… https://t.co/WwdWuWHXEn
# RT @lilgnar: why they don’t put a rico on the kkk
# RT @SportsCenter: Never forget this Kurt Angle story 😳 https://t.co/a1pXKqVnwl
# RT @AidenJeter: I will be signing my NLI tmrw in the PAC @ 6! Come out and Support the guys and I! https://t.co/tmsMvUzrhC
# Tomorrow 🔊🔊🔊
#
# #GigEm https://t.co/hbrIW8Vu0E
# 🚨 Signing Day is less than 24 hours away 🚨
#
# Join us at the 247Sports YouTube channel as we plan on keeping you cove… https://t.co/LU3VwqC1Ci
# Every 5-star in college football's 2023 recruiting class heading into #SigningDay: https://t.co/cTKG62S8H7 https://t.co/uuKeQvWUkU
# 📍 Billy Bob's Texas
#
# #SicEm | #PersonOverPlayer https://t.co/XTh3rZOAJH
# RT @_MLFootball: Happy B-Day @presidentjacc!!!!!!!
# Will four-star DB Daylen Austin flip from LSU to Oregon?
#
# @adamgorney looks at the 12 most likely Signing Day flip… https://t.co/teD3UKtBR8
# RT @NFL: VOTE for the @FedEx Air Player of the Week!
# RT @ReggieBush: I wonder why the NCAA has gone quiet on me? They had a lot to say last year.  These are some pretty serious allegations. Do…
# RT @VinceB1125: 110% COMMITTED https://t.co/U9CjluG2jW
# RT @ReggieBush: The truth is the NCAA’s ONLY WITNESS is a convicted felon who was in prison for rape, months before he sat down with the NC…
# Will TCU flip four-star cornerback Jayvon Thomas?
#
# @RivalsNick takes a look at six prospects in the Mid-South regio… https://t.co/Whu4gTNE2B
# Jaden Rashada looks to bring the Gators back to the national spotlight. https://t.co/DxE9wCl1fE
# Career-high in receptions (10) ✔️
# Career-high in receiving yards (157) ✔️
#
# @KJ_Osborn was born for this. https://t.co/fHC4r3Gug1
# RT @DushawnLondon1: On Sunday, Arizona landed its first commitment in the class of 2024 with top 30 shooting guard Jamari Philips. He break…
# One of the top prospects in the class of 2024, Ian Jackson is ready for his Jan. 6 official visit to North Carolina… https://t.co/J3Nkclf9wB
# Caleb Downs is a rare prospect. What's he bringing to the table? https://t.co/cU8WxMZbOv
# RT @SWiltfong247: Nashville (Tenn.) Lipscomb Academy QB Hank Brown offered by #Auburn today. “I think they are going to have a lot of succe…
# RT @SWiltfong247: 247Sports Composite four-star DL Dylan Spencer talks about his commitment to #TexasTech here. https://t.co/zidg2rSXEZ
# 🚨National Signing Day Preview🚨
#
# @Andrew_Ivins &amp; @cpetagna247 discuss the teams to watch on National Signing Day, wh… https://t.co/CcWrfXxjSv
# RT @SWiltfong247: The nation's No. 1 OT Kaydn Proctor drops his signing details for Wednesday morning: https://t.co/8Vbxs3R0Xf
# RT @SWiltfong247: More on 247Sports No. 1 OT Kadyn Proctor who will sign with the school of his choice Wednesday morning. He talks about hi…
# RT @SWiltfong247: Signing Day Eve 2022 Intel: #Alabama #Georgia and #Miami aim to add to top three classes, another Top247 QB pondering a c…
# RT @SWiltfong247: I think #SouthCarolina is in strong position to flip in-state four-star QB LaNorris Sellers who had a terrific senior sea…
# RT @SWiltfong247: #NorthCarolina has the nation's No. 25 recruiting class and trending for talented Peach State running back heading into t…
# #NSD2022 Primer: A class overview and #Wisconsin's storylines for Signing Day
#
# https://t.co/v1QYFu643a
# Army star LB Andre Carter will be able to seek a waiver to enter the 2023 NFL Draft, per Pete Thamel. A recently pa… https://t.co/mORnAXwveV
# Jermaine O'Neal Jr. is making a name for himself on the recruiting scene
#
# ✍️ @BJenkins247
#
# https://t.co/bQMjoqIeD5 https://t.co/PVqmIp3BIY
# It’s truly remarkable how fast professional Track &amp; Field athletes are. Never gets old. How many of you recruits wo… https://t.co/YmWhZENwCf
# RT @jcusports: ICYMI: Jeff Behrman '95 is our new head football coach!
#
# LSU Special Teams Coordinator &amp; Recruiting Coordinator @BrianPolian…
# The most wonderful time of the year 🥹 https://t.co/f4z4d45KJS
# .@adamgorney spotlights more than a dozen high-profile prospects that could flip their commitments this week:… https://t.co/XgWcHOaeYx
# RT @PratikxPatel: The Argentinian National Team brought 6,000 pounds of beef with them to the World Cup
#
# The Winners eat meat 🏆 https://t.c…
# RT @CoachDanCasey: "When the best players on your team are the best people on your team, you have a great opportunity to have great unity o…
# posted. 🔔
#
# Hit the link to shop 🔗 https://t.co/GJHKoWVNhy https://t.co/JwFf1ZZIyy
# 👀 . . https://t.co/IVONFQyI58
# After winning four major awards, Alabama star Will Anderson credited older teammates for instilling belief in him e… https://t.co/kbj4NAbihy
# The 2023 JUCO rankings have been released. Here's a closer look at the top 10: https://t.co/EW9wXEvXxh
# RT @christyporter51: @Coach_Elby @CoachTerryPSU 1000%. Correct!  The Porter family will forever be grateful to Coach Terry Smith &amp; the enti…
# It's time to vote for the @budlight #BudLightCelly of the Week!
# Y’all just wait. The rest of college football isn’t ready for what the #PonyExpress is about to look like 👀
#
# Just g… https://t.co/TrQq3wVdff
# Latest intel on Grayson McCall, Devin Leary, other uncommitted top transfer QBs ahead of Signing Day:… https://t.co/lWJ2C7PXcB
# Yesterday, Texas Tech landed three-star Justin "Sensei" Horne.
#
# "They're gonna learn who Sensei is, and they're gon… https://t.co/fXandYdheU
# Happy Birthday, @alfahiym3!
#
# #SicEm | #PersonOverPlayer https://t.co/6Ebk4XBK4g
# .@RWrightRivals makes his predictions on some of the top storylines looming in the Southeast with National Signing… https://t.co/sFz5VesQIT
# 🚨 Signing Day is less than 24 hours away 🚨
#
# Join us at the 247Sports YouTube channel as we plan on keeping you cove… https://t.co/aaHIG92C2x
# Just 2⃣4⃣ hours until #NSD23! #4sUp https://t.co/AflNRFY9VH
# Feeling blue. 🔔
#
# Hit the link to shop 🔗 https://t.co/GJHKoXdo96 https://t.co/vXr79Iqumy
# Could Georgia flip four-star receiver Deandre Moore?
#
# @AdamGorney has these five predictions about West Region pro… https://t.co/wB78NUpGpL
# Are you willing to let go of what you have now to get what you want in the future? #faith https://t.co/k0ZS6afPRO
# Friendly reminder that it's 5 days to Christmas ✨
# RT @IDPotatoBowl: MASH BASH 2022 IS IN THE BOOKS 🎶🥁🎺🎷
#
# #ETOUGH | #AllSpartans https://t.co/kHGHYr9Eba
# 2 people followed me // automatically checked by https://t.co/iCixO321rm
# And the Anthony Silvestri game a few years later in Goleta. https://t.co/oJtrZmgF02
# There have really only been two games where I say that’s the ________ (insert name here) ______ game.
#
# The Matt Ti… https://t.co/3ke8WJpqpm
# To be clear - my photos were what was trash that night. Sometimes still are. 🤣
# RT @GordonTredgold: Being honest and open is the only way to convince cynical employees that you truly want to establish a partnership with…
# RT @JR_Sandlin: RECRUITs: Most rosters are built on regions. As you send film out to schools, focus on ALL schools (FBS, FCS, D2, D3, NAIA,…
# Cal Poly at sjsu tomorrow for the first time since Silicon Valley legend @mtitch12 put the Spartans away late in th… https://t.co/IChy0a4sjT
# Jags or Jets? See you in Week 16.
#
# #JAXvsNYJ— Thursday 8:15pm ET on Prime Video
# Also available on NFL+… https://t.co/OoUbuGmScj
# RT @bnice21: @will_herb_stone Especially in the NIL-era where athletes are creators (s/o to @KirbyPorter_) and athletes are also brands (s/…
# My dawg since way back! The tape is cold 🥶 👀 https://t.co/JSmtsycyAs
# YESSIR!!! RUN IT BACK🟣🟡🐺☔️ #BowDown https://t.co/LAMXVBUBLE
# RT @aguayo_aiden: After a great official visit to Utah Tech i’m blessed to say i’ve received my 2nd D1 offer. @JSerra_Football @CoachT_JSer…
# RT @ZZJONES23: After a great conversation with @CoachDreAllen26 I am blessed to receive an offer and announce my commitment to UC Davis. I…
# RT @toddowyoung: Me after a client asks for one last edit from a photoshoot.
# ASCEND https://t.co/rBz2ALwmRT
# RT @COSAthletics: The COS Sequoias Stadium build breaks ground today. Completion date July 23’  LETS GO!!!!! https://t.co/IytEo6qYKk
# RT @NextGenStats: Aaron Rodgers completed 10 of 12 passes for 93 yards against the blitz in Week 15 (+9.7% CPOE).
#
# Rodgers vs the Blitz (20…
# RT @packers: 🤟 @AaronRodgers12 🤟
#
# #GoPackGo https://t.co/QMiC0yB6ie
# RT @HerdFB: How sweet it is! 🏆🏖️
#
# #WeAreMarshall https://t.co/xst651FaBl
# RT @HerdFB: There was just something special about this team! 🏆
#
# #WeAreMarshall https://t.co/KQdBCuvZTD
# A-Rod x Baker. Respect. https://t.co/lPmwX5y067
# RT @Tmarcuss: After a great conversation with @FredrickTate2 I am blessed to receive a D1 scholarship offer from @TarletonFB @JLira2 @Coach…
# RT @israel_polk: H2P😎 https://t.co/Nq3ITMP1bT
# RT @Jonathanlandryy: all thanks to God ❤️ @EWUFootball https://t.co/wiYTaCXM1h
# RT @ArcellesJohnson: Blessed to receive a D1 scholarship offer to university of Nevada @NevadaFootball @CoachAArceneaux @CoachKWils @CoachS…
# RT @BoenPhelps: After a great call with @EWUCoach_Bruce I am proud to say I have received a PWO from Eastern Washington University! Go Eags…
# RT @perseuslatu801: After many great conversations with @Janimal84 I am very humbled and blessed to receive an opportunity to continue my e…
# RT @SamuelDunnell: HOME📍🖤❤️ https://t.co/06IL4M4ZHj
# RT @RivalsPortal: Lil’ Wayne gave five-star Jackson State transfer Travis Hunter a shoutout on tonight’s Monday Night Football Manningcast…
# FINAL: @packers keep their playoff hopes alive! #LARvsGB #GoPackGo https://t.co/Y3fEl76LBA
# I lost by 4 which I would have got with a TD to end there. https://t.co/9wJFTA2sXi
# First 10-loss season for Sean McVay as well https://t.co/wAf1XTNb03
# Here are some reps from Team 3 Stripe OL/DL one on ones.
#
# @FBUAllAmerican
#  |
# @RWrightRivals
#  |
# @RivalsWoody
#  |… https://t.co/VrY7TB8UVc
# Consistency.
# .@Packers fan @LilTunechi joins the Manningcast 🧀 https://t.co/lLSYMmPAcJ
# RT @TheMatt_V: See You Wednesday Night Brotha 👊🏼 &amp; @cookiesmom_ @Coooks99 Enjoy Disney World.
# RT @MBBowlGame: Pure joy. 💚🦬
#
# @HerdNation @HerdFB @HerdZone https://t.co/uzbHGWSpwr
# It’s @HawaiiBowl game week!
#
# #TheTimeIsNow | #AztecFootball100 https://t.co/emrgJzsFUx
# .@jalenramsey takes it away! 😮
#
# 📺: #LARvsGB on ESPN
# 📱: Stream on NFL+ https://t.co/GEDpprVg3K https://t.co/wMRlmkhp0m
# There was an attempt.
#
# 📺: #LARvsGB on ESPN
# 📱: Stream on NFL+ https://t.co/GEDpprVg3K https://t.co/m3i3lScxIs
# RT @fenwickfriars: PRAYERS, ASSISTANCE NEEDED: #FenwickFriars alumnus Pete Salvino '15 went missing early Sun. morning 12/18 in Lincoln Par…
# Rasul Douglas gets the interception!
#
# 📺: #LARvsGB on ESPN
# 📱: Stream on NFL+ https://t.co/GEDpprVg3K https://t.co/Ma5DnCnJNW
# Green Bay nearly pulled a Patriots...
# Seen Leonard Floyd deliver games like this one.
#
# But the first for this season.
# RT @uscfb: Leaving a legacy and earning a spot on our All-American Walk. 😤✌️ https://t.co/pwLBqasnDL
# .@keiseannixon might be one of the best returners in the league 👏
#
# 📺: #LARvsGB on ESPN
# 📱: Stream on NFL+… https://t.co/e7ra6la1Jg
# RT @Sprtsmomonthego: Bay Areaaaaaaaa!  When it’s Gods Plan there’s not much you have to explain!  #2 in full effect. #Spartans #Dunksordered
# .@bakermayfield throws a strike to @Ty_Higs19 for a @RamsNFL TD! 🙌
#
# 📺: #LARvsGB on ESPN
# 📱: Stream on NFL+… https://t.co/nRl5uLcZNI
# Focused on Wednesday like it’s a game day! The #BRADDAHHOOD is growing!
#
# #GoBows #NSD23 #Ri23OfTheWarrior https://t.co/o0RnhiMl9F
# Chivas are back’
# RT @MatthewBailiff1: COMMITTED #BRADDAHOOD @CoachTimmyChang @ursua05 @Jeff_Reinebold @UH_SClapham https://t.co/BmIAWMCukT
# RT @Maxwellp3terson: Blessed to receive an offer to Portland state university! Thank you for believing in me @cfry_05 @coachapatterson http…
# RT @JacobT_72: After a great call with @Tj_Peer I’m blessed to have earned a PWO offer to @SUUFB_! Go Thunderbirds! @delanefitz @CoachATrai…
# RT @JrSia2: Yessir less gettt ittttt!!!!!💙💙 #AggieUp @CoachMeifu @Coach_Matthews_ @JackPay17 https://t.co/t7DK1DdDtg
# RT @Maxwellp3terson: Blessed to receive an offer to UNLV. Thank you for believing in me @CoachBPetrino @Coach_Odom @KelseaWinkle https://t.…
# RT @christianearlss: Blessed to announce that I have received an offer from University of Nevada, Las Vegas! #AGTG https://t.co/yFqgoyMMop
# RT @BottMulitalo: Thank you @CoachPowell99 for giving me an opportunity and giving me my first Division 1 offer to the University of Utah‼️…
# RT @StoneMulitalo: Blessed to have been given a chance to further my educational and football career at Brigham Young University 💯 #GoCougs…
# RT @1stevenortizjr: Committed and ready to work @UMassFootball @FBCoachDBrown @CoachMLiv #Flagship 🚩 #dUdeMASS23 https://t.co/Jzlwl9o0H7
# RT @Bigvin78: Your favorite GA crew.
#
# #FriscoBowlChamps
#
# @showtime_jaye @17keithprice @CoachYams https://t.co/5mzx8ean78
# RT @Tmarcuss: After a great conversation with @Coach_MarkRhea I’m blessed to receive a D1 scholarship offer from @psuviksFB…
# The last time the Rams had double digit losses was in 2016, the 4-12 season.
#
# They're staring at their 10th loss right now at Lambeau.
# RT @Nick_haynes80: Blessed to receive an offer from Southern Utah university 🔴🙏🏾 https://t.co/2iOhoCNFsV
# RT @kylanweisser11: After a great conversation with @schaferwiu I am proud to say that I have received a full ride scholarship to play foot…
# RT @kenyon_shabazz: After a great talk with @Coach_Fishback I am blessed to receive my first full ride offer from Missouri State! Thank You…
# RT @alonzo10_isaiah: A Long Time Coming! @USUFootball @coastfball https://t.co/79bPCeO1FQ
# RT @tym4_: Thank you to everyone who has helped me throughout this crazy process. Very blessed and grateful for this opportunity. Let’s get…
# RT @AidanCarter10: After many great conversations with @CoachBestEWU and @CoachChapin I am very excited to announce I’ve been offered and h…
# RT @BrysonSnelling9: Thank you @JoeAshfield for my first offer to play college football! @CoachMarkCooley @Coach_Snelling https://t.co/jGqj…
# RT @JayrobII: Blessed to receive my second offer to Fresno State !🙏🏾 https://t.co/kzF6fahSHR
# RT @JasonThome12: After a great conversation with @coachnighttrain I’m grateful to have received and offer to Black Hills State University!…
# We still on 20% off 3 days left on the sale guys https://t.co/UZhjiAhPn1
# BIG COMMIT!!! https://t.co/lS1MRVUKNO
# Need a ride?
#
# 📺: #LARvsGB on ESPN
# 📱: Stream on NFL+ https://t.co/GEDpprVg3K https://t.co/zaUoeZCfEb
# RT @Mailoto55: Let’s Work Tucson
#
# @mtsacfootball @CoachKaufusi @CoachNansenUofA @bolin_theodore @IonaCoach
# @rickyhunley @lone_toailoa http…
# It’s @Showtyme_33! Green Bay extends the lead.
#
# 📺: #LARvsGB on ESPN
# 📱: Stream on NFL+ https://t.co/GEDpprVg3K https://t.co/mzTTbDRh2c
# RT @dylanjcamp: Thank you to god! My 2nd Division 1 full scholarship offer to Eastern Illinois University @D_Gomes24 @KevinAlmlie https://t…
# RT @DiegoB_14: Hard work pays off, God is good 🙏🏼 COMMITTED!!! @Temple_FB https://t.co/4NuKckzJ87
# RT @Jasonharris_4: GOD DID!!!! I’m blessed to receive my FIRST offer from the university of Houston Baptist university! THANK YOU JESUS. TH…
# New and IMPROVES tongkat ali, guys it's something else! https://t.co/0IJhj1HME5
# RT @Trendingjoey: After talking with @JustinCrouse7 &amp; @CoachAdamFuller I am blessed to receive a opportunity to play at Florida State Unive…
# RT @Moneymike61: EWU here we come🖤GO EAGS🦅🦅#committed https://t.co/S9U6BljisN
# RT @RyanBer21968336: After a home visit with @coachely89, I received a full scholarship offer from Portland State University!! Thank you @p…
# RT @john_taumoepeau: After many great conversations with @Janimal84 I am very humbled and blessed to receive an opportunity to continue my…
# RT @Johnblapuz: Blessed to announce that I have earned another Division 1 offer to play at University of Nevada🐺 #GoPack @Angus_McClure @co…
# RT @brycefelt22: Thank you God for this opportunity!! Blessed to announce that after a great talk with @CoachCav10, I have received a divis…
# RT @TrejanBridges: More than BLESSED this past weekend up at Tennessee Tech for my first OV!! ☔️🦅
#
# WINGS UP!
#
# #AGTG https://t.co/yOmwkNynJb
# RT @AF_Falcons: Lucky to call this place 𝓱𝓸𝓶𝓮 😍 https://t.co/VllZ3m2z4A
# RT @KingjosephE: ⁦@SCOOBZILLA730⁩ I have so much to prove TO MYSELF! really working on becoming the BEST version of myself! I will admit at…
# The Sauce loves the cold.
# https://t.co/eCzfLtn3rI
# RT @PatMcAfeeShow: AJ DILLON IS A DAWWWWGGGGGGGGG
# Peyton and @RayLewis vs. @EliManning and @DemarcusWare
#
# Which #ProBowlGames coaching staff are you rolling with?
#
# 📺… https://t.co/McqMa6g8WR
# Future is bright for @packers rookie LB Quay Walker 😎
#
# 📺: #LARvsGB on ESPN
# 📱: Stream on NFL+ https://t.co/GEDpprVg3K https://t.co/Lw5ZutgEfo
# RT @Vol_Football: ‼️ Soon ‼️
#
# #GBO 🍊| #RockyTop23 https://t.co/OH7RvSkvKP

# %% [markdown]
# ### Collecting tweets that have Airbnb and Housing Market in it

# %%
# Collecting tweets that have Airbnb and Housing Market in it 
Tweets_Housing= []
Airbnb_tweets7 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate = 202201010000,
                                       maxResults = 100, toDate = 202202010000) 

for tweet in Airbnb_tweets7: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 34

# %%
# Collecting tweets that have Airbnb and Housing Market in it 
Airbnb_tweets8 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate = 202202010000,
                                       maxResults = 100, toDate = 202203010000) 

for tweet in Airbnb_tweets8: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 134

# %%
# Collecting tweets that have Airbnb and Housing Market in it 
Airbnb_tweets9 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate = 202203020000,
                                       maxResults = 100, toDate = 202204010000) 

for tweet in Airbnb_tweets9: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 234

# %%
# Collecting tweets that have Airbnb and Housing Market in it 
Airbnb_tweets10 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate = 202204020000,
                                       maxResults = 100, toDate = 202205010000) 

for tweet in Airbnb_tweets10: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 334

# %%
# Collecting tweets that have Airbnb and Housing Market in it 
Airbnb_tweets11 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate = 202205020000,
                                       maxResults = 100, toDate = 202206010000) 

for tweet in Airbnb_tweets11: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 434

# %%
# Collecting tweets that have Airbnb and Housing Market in it 
Airbnb_tweets12 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate = 202206020000,
                                       maxResults = 100, toDate = 202207010000) 

for tweet in Airbnb_tweets12: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 534

# %%
# Collecting tweets that have Airbnb and Housing Market in it 
Airbnb_tweets13 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate =202207020000,
                                       maxResults = 100, toDate = 202208010000) 

for tweet in Airbnb_tweets13: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 634

# %%
Airbnb_tweets14 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate =202208020000,
                                       maxResults = 100, toDate = 202209010000) 

for tweet in Airbnb_tweets14: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 734

# %%
Airbnb_tweets15 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate =202209020000,
                                       maxResults = 100, toDate = 202210010000) 

for tweet in Airbnb_tweets15: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 834

# %%
Airbnb_tweets16 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate =202210020000,
                                       maxResults = 100, toDate = 202211010000) 

for tweet in Airbnb_tweets16: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 934

# %%
Airbnb_tweets17 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate =202211020000,
                                       maxResults = 100, toDate = 202212010000) 

for tweet in Airbnb_tweets17: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 1034

# %%
Airbnb_tweets18 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate =202212020000,
                                       maxResults = 100, toDate = 202212090000) 

for tweet in Airbnb_tweets18: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 1088

# %%
Airbnb_tweets19 = api.search_full_archive(query ='"Airbnb" "Housing Market"' , label ='NewWebAnalyticsProject', fromDate =202212100000,
                                       maxResults = 100, toDate = 202212190000) 

for tweet in Airbnb_tweets19: 
    Tweets_Housing.append(tweet.text) 
print(len(Tweets_Housing))
# Out:
# 1188

# %%
print(Tweets_Housing)
# Out:
# ["Airbnb and it's consequences have been a disaster for the housing market https://t.co/2n9AYgNqO7", '@GeorgeMonbiot An Airbnb tax? So the cost of Airbnb goes up? A windfall tax on gas companies? Taxing them as the co… https://t.co/feduGrizhC', '@ofvariousstorms The housing market in general needs to tank because tell me why my town of 45K people has 5 availa… https://t.co/oKR3SDttur', 'The death of our housing market is going to be because of companies like AirBNB &amp; Zillow. Just watch. This time the… https://t.co/SVR2LA8N7R', "What to expect from the housing market in 2022: Another sellers' market\n\nhttps://t.co/fcRcJMoXsZ\n\n#realestatetech… https://t.co/2UySKE4I38", 'The author forgot to mention the negative impact Airbnb has on neighbors and the housing market, but I agree - Airb… https://t.co/qV0oW4jw0S', 'NEW FULL-TEXT: "Airbnb and the housing market in Italy. Evidence from six Cities" by Congiu et al. https://t.co/tuVjlA6on2', 'Is the #NYC Housing Market Crushing your #airbnb  Dreams? | MLS Search &amp; An... https://t.co/bhQCxSXYTH via @YouTube \n\n#HoltonWiseTV', 'Is the NYC Housing Market Crushing your Airbnb Dreams? | MLS Search &amp; An... https://t.co/bhQCxSXYTH via @YouTube', '@pdf00587301 @LawrenceLepard I grew up in Vail and the recent inflation has destroyed the Eagle County housing mark… https://t.co/DSfuVMej5c', 'Airbnb is one of the worst things to happen to the housing market and should be banned in most communities idc idc idc', 'Also, attracting outside investments that displace Puerto Ricans and lock them out of their housing market is a har… https://t.co/iAEHeduvTl', '@agonadon @hook_taylor @bchesky Do you run the Airbnb out of the home in which you also live? That would be a big d… https://t.co/sIu0t5J1jw', '@alloalouette @smolbutfeisty It’s this kind of speculating that’s driving up the housing market. People buying sing… https://t.co/VUXPtUnF3X', 'Does anyone else here feel complicit in further ruining the housing market by using airbnb to hire out houses? If t… https://t.co/j0TQLyY9qr', '@chigrl Owners equivalent rent weights for 32.8% of CPI made by the Bureau of Labour Statistics.\nThat measure in it… https://t.co/gY74LihM88', 'Fascinating thread. \n\nCould this reshape the housing market? If demand shifts to “short-term” rentals and communiti… https://t.co/bsPoz1REOl', "@bchesky hope you'll make time to understand how airbnb is affecting the local housing market everywhere you go!", '@jamesjhaeck @monkeyking On the one hand, I really don’t like AirBnB’s business model, their impetus for tax avoida… https://t.co/etmRQtT6x6', 'RT @hauspostnews: JANUARY 17, 2022 - @LandlordToday \nAirbnb and short lets wreck local housing markets, say conservationists\nhttps://t.co/Q…', 'JANUARY 17, 2022 - @LandlordToday \nAirbnb and short lets wreck local housing markets, say conservationists… https://t.co/BxKARatzag', 'Has the housing market around you had a recent boom in short term rentals?\n\n#propertymarket #Airbnb #shortlets… https://t.co/LYzGgfCAI1', 'RT @termite_terry: @smh @elizabethredman Airbnb boasts we\'re their "most penetrated market in the world". Why couldn\'t local councils be ma…', '@smh @elizabethredman Airbnb boasts we\'re their "most penetrated market in the world". Why couldn\'t local councils… https://t.co/3O0Gs3RExZ', '@LHSyd Airbnb boasts we\'re their "most penetrated market in the world". Why couldn\'t local councils be mandated to… https://t.co/sgNtH6iA6O', 'The Fed literally created the Gig Economy (Airbnb, Uber) with the housing market bubble and the 2008 crash. Ppl on… https://t.co/ZjvhG2rW6w', "@DonDona26811517 @AP Housing market has it's own dynamics from the growth in corporate landlords, foreign land purc… https://t.co/k65jO63EnI", 'Investment properties used as an ever growing Airbnb pool are killing the housing market. Both for families trying… https://t.co/IbuXSV9QGT', '@letsgetitbetter @GG37374104 I wonder how many of those investors in Vic are using them for month to mo ...

# %%
Dframe = pd.DataFrame(Tweets_Housing, columns = ['HM_Tweets']) 
Dframe.to_csv('2022_HM_Tweets.csv', index= False )

# %% [markdown]
# ### Collecting Tweets with just Airbnb in it

# %%
# collecting tweets that have Airbnb in it
Tweets = []
Airbnb_tweets2 = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202201010000,
                                       maxResults = 100, toDate = 202202010000) 

for tweet in Airbnb_tweets2: 
    Tweets.append(tweet.text) 
print(len(Tweets))
# Out:
# 100

# %%
Airbnb_tweets3 = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202202010000,
                                       maxResults = 100, toDate = 202203010000) 

for tweet in Airbnb_tweets3: 
    Tweets.append(tweet.text) 
print(len(Tweets))
# Out:
# 200

# %%
Airbnb_tweetsD = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202203010000,
                                       maxResults = 100, toDate = 202204010000) 

for tweet in Airbnb_tweetsD: 
    Tweets.append(tweet.text) 
print(len(Tweets))
# Out:
# 300

# %%
Airbnb_tweetsO = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202204010000,
                                       maxResults = 100, toDate = 202205010000) 

for tweet in Airbnb_tweetsO: 
    Tweets.append(tweet.text) 
print(len(Tweets))
# Out:
# 400

# %%
Airbnb_tweetsL = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202205010000,
                                       maxResults = 100, toDate = 202206010000) 

for tweet in Airbnb_tweetsL: 
    Tweets.append(tweet.text) 
print(len(Tweets))
# Out:
# 500

# %%
Airbnb_tweets = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202206010000,
                                       maxResults = 100, toDate = 202207010000) 

for tweet in Airbnb_tweets: 
    Tweets.append(tweet.text) 
print(len(Tweets))
# Out:
# 600

# %%
Airbnb_tweetsN = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202207010000,
                                       maxResults = 100, toDate= 202208010000)
for tweet in Airbnb_tweetsN: 
    Tweets.append(tweet.text)
print(len(Tweets))
# Out:
# 700

# %%
Airbnb_tweetsU = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202208010000,
                                       maxResults = 100, toDate= 202209010000)
for tweet in Airbnb_tweetsU: 
    Tweets.append(tweet.text)
print(len(Tweets))
# Out:
# 800

# %%
Airbnb_tweetsF = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202209010000,
                                       maxResults = 100, toDate= 202210010000)
for tweet in Airbnb_tweetsF: 
    Tweets.append(tweet.text)
print(len(Tweets))
# Out:
# 900

# %%
Airbnb_tweetsG = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202210010000,
                                       maxResults = 100, toDate= 202211010000)
for tweet in Airbnb_tweetsG: 
    Tweets.append(tweet.text)
print(len(Tweets))
# Out:
# 1000

# %%
Airbnb_tweetsH = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202211010000,
                                       maxResults = 100, toDate= 202212010000)
for tweet in Airbnb_tweetsH: 
    Tweets.append(tweet.text)
print(len(Tweets))
# Out:
# 1100

# %%
Airbnb_tweetsQ = api.search_full_archive(query =('Airbnb' or '#Airbnb' or '@Airbnb'), label ='NewWebAnalyticsProject', fromDate = 202212010000,
                                       maxResults = 100, toDate= 202212170000)
for tweet in Airbnb_tweetsQ: 
    Tweets.append(tweet.text)
print(len(Tweets))
# Out:
# 1200

# %%
Df = pd.DataFrame(Tweets, columns = ['Tweets']) 
Df.to_csv('2022_Tweets.csv', index= False )

# %%
print(Tweets)
# Out:
# ['ルールメイキングの基本は、アジェンダシェイピング。何を争点に置いて、利害関係者をどのタイミングで巻き込んで、どの方向にもっていくか。記事中にあるUberとAirbnbの明暗を分けた事例は大変参考になりますね。\n\n渉外...… https://t.co/Y6uDjTuhIN', 'oomfs going to wembley n2 and wanna do a big harrie airbnb COME FIND ME!!!', 'RT @BuzzPatterson: I propose that Canadians and Californians get together and banish our soy boys @JustinTrudeau and @GavinNewsom to an isl…', 'RT @SunilDa56757277: #app #application #appdesign #appdesigner #videogame #conceptart #digital #education #airbnb #lightroom #editing #Inst…', 'RT @SunilDa56757277: #app #application #appdesign #appdesigner #videogame #conceptart #digital #education #airbnb #lightroom #editing #Inst…', "from what i'm understanding (and i have brain damage so i'm prob wrong, pls correct me)\n\nif you film anywhere in pu… https://t.co/Uta4HdrE38", 'RT @SunilDa56757277: #app #application #appdesign #appdesigner #videogame #conceptart #digital #education #airbnb #lightroom #editing #Inst…', '@harrysbrasil airbnb muito provavelmente', 'Pourquoi les hôtels, airbnb sont si chère 🥲', 'RT @SunilDa56757277: #app #application #appdesign #appdesigner #videogame #conceptart #digital #education #airbnb #lightroom #editing #Inst…', 'RT @BuzzPatterson: I propose that Canadians and Californians get together and banish our soy boys @JustinTrudeau and @GavinNewsom to an isl…', 'RT @harrysbrasil: Gostaríamos de saber quem vai no show de Curitiba pretende se hospedar em hotel, hostel ou Airbnb?', '@Airbnb gift vouchers make for the best presents.', '@marquisletigre @Jyates5 With the Airbnb that is, vacation rental, pad split for travel workers?', 'Has the potential to be the greatest AirBnB ever. https://t.co/HEhNambqSK', 'Gostaríamos de saber quem vai no show de Curitiba pretende se hospedar em hotel, hostel ou Airbnb?', 'RT @CityofSanDiego: Are you an Airbnb or Vrbo host? Do you own or manage a vacation rental in San Diego? Sign up now for email updates on s…', "@kezia420_ So that sounds like if the owner of an Airbnb happened to see your film and complain, that's an issue. B… https://t.co/yAi3O8SmWw", 'RT @GeorgeMonbiot: There are much fairer ways of raising revenue than higher National Insurance. \nEg\nA wealth tax.\nA higher top income tax.…', "RT @elderofziyon: Here's some context: @Amnesty has written FAR more pages about AirBnB and TripAdvisor listing Jewish-owned homes than it…", 'RT @BuzzPatterson: I propose that Canadians and Californians get together and banish our soy boys @JustinTrudeau and @GavinNewsom to an isl…', 'RT @BuzzPatterson: I propose that Canadians and Californians get together and banish our soy boys @JustinTrudeau and @GavinNewsom to an isl…', '@ActuallyyJP List it as “a cosy studio with a killer view and plenty of natural light” on @Airbnb for $350 a night', 'pensando Nela  https://t.co/miioJ6icOi', 'Virtual AirBnb ideas testers needed #VirtualReality  https://t.co/P8zADkWLmD', 'Virtual AirBnb ideas testers needed #VirtualReality via https://t.co/aPd14AOUQU https://t.co/5SwPYxMpry', '@zazambeli no airbnb que eu fiquei com a Ju no rio, que no caso era apartamento\no motoboy subiu no apê vei tendi na… https://t.co/fn145lHtUM', 'Virtual AirBnb ideas testers needed #VirtualReality via https://t.co/IpwvZJYjo6 https://t.co/hNn5Vihg5V', "@antifacatdept Hi there, at this time, this feature is not available on the platform, however, we'll be sure to sha… https://t.co/fQtl2mfZUp", 'RT @PolyAfterDark_: POLY GONE WILD ~ Takes Over Orlando | March 18th-20th, 2022\n\nContent Creator Package Includes\n • 2 night Airbnb Stay (…', 'Red Flags To Look For When Booking An  #Airbnb https://t.co/iYoRSdyXqD', 'Next meetup gotta be at an airbnb or someone else’s place, im begging', '@SamuelBeek To do (Reminders, todoist, things)\nScheduled rides (uber)\nTrips (Airbnb.. your upcoming trip)\nBooks (Go… https://t.co/WnRZXw7Pif', '@PiperThread Puedes usarla como airbnb, ya pagaste la estancia con tus impuestos.', 'So @alexkatson @LukeCarrNFL and I are talking about QB’s in the AirBnB. If you were forced  ...

# %%
print(len(Tweets))
# Out:
# 1200

# %% [markdown]
# Yes! We got a bunch of tweets from our timeline!
#
# This isn't practically very helpful, but it shows us how we can use Twitter's API to get data. In fact, Tweepy API is a really powerful tool:
# - it has many methods that we can use
# - it gives us a very convenient way to fetch large volumes of data
